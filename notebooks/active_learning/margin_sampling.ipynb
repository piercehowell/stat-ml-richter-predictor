# %% [markdown]
# ## Try various margin sampling (active learning technique) with embedding model 2
#
# ### Let's use embedding model 2, trained on only 500 datapoints

# %%
import pandas as pd
import numpy as np
import os
from sklearn import preprocessing 
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import tensorflow as tf

data_dir = "../../data/"
train_vals_df = pd.read_csv(os.path.join(data_dir, "train_values.csv"))
train_labels_df = pd.read_csv(os.path.join(data_dir, "train_labels.csv"))

# get categorical data
X1 = train_vals_df[["geo_level_1_id", "geo_level_2_id", "position", "foundation_type", "roof_type", "ground_floor_type", "other_floor_type", "plan_configuration", "legal_ownership_status"]].to_numpy()

enc = OrdinalEncoder()
enc.fit(X1)
X1 = enc.transform(X1)

## get numerical data
df = train_vals_df[[
'count_floors_pre_eq',
'age',
'area_percentage',
'height_percentage']]

# normalize numerical data
min_max_scaler = preprocessing.MinMaxScaler()
X2 = min_max_scaler.fit_transform(df.values)


# get labels

y = train_labels_df["damage_grade"].to_numpy()
y = np.eye(3)[y-1]

X = np.concatenate((X1,X2), axis = 1)
# X = np.asarray(X).astype('float32')

# %%
rng = np.random.RandomState(7)
perm = rng.permutation(range(len(X)))
X_rand = X[perm]
y_rand = y[perm]

seedSize = 500
X_train = X[:seedSize ]
y_train = y[:seedSize ]

# unlabeled dataset
X_u = X[seedSize :int(.7*len(X))]
y_u = y[seedSize :int(.7*len(X))]

X_val = X[int(.7*len(X)):int(.85*len(X))]
y_val = y[int(.7*len(X)):int(.85*len(X))]
X_test = X[int(.85*len(X)):]
y_test = y[int(.85*len(X)):]

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,Dense, Embedding

checkpoint_filepath = '/tmp/saved_models'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_categorical_accuracy',
    mode='max',
    save_best_only=True)

## Creating the layers
batch_size = 2048
input = Input(shape=(13,)) 
embedding0 = Embedding(31, 2)(input[:,0]) # geo id 1
embedding1 = Embedding(1428, 2)(input[:,1]) # geo id 2
embedding2 = Embedding(4, 2)(input[:,2]) # position
embedding3 = Embedding(5, 2)(input[:,3]) # foundation type
embedding4 = Embedding(3, 2)(input[:,4]) # roof type
embedding5 = Embedding(5, 2)(input[:,5]) # ground floor type
embedding6 = Embedding(4, 2)(input[:,6]) # other floor type
embedding7 = Embedding(10, 3)(input[:,7]) # plan configuration
embedding8 = Embedding(4, 2)(input[:,8]) # legal ownership status
Layer_1 = Dense(20, activation="relu")(tf.concat([embedding0,embedding1,embedding2,embedding3,embedding4,embedding5,embedding6, embedding7, embedding8, input[:,9:]], 1))
# Layer_1 = Dense(20, activation="relu")(tf.concat([embedding0,embedding1,embedding2,embedding3,embedding4, input[:,5:]], 1))
Layer_2 = Dense(15, activation="relu")(Layer_1)
Layer_3 = Dense(10, activation="relu")(Layer_2)
output_layer= Dense(3, activation="softmax")(Layer_3)

model = tf.keras.Model(inputs=input, outputs=output_layer, name="emb_model")
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss='CategoricalCrossentropy', metrics=['CategoricalAccuracy'])
history = model.fit(X_train, y_train, epochs=100, batch_size=batch_size, validation_data=(X_val, y_val), callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 1.0947 - categorical_accuracy: 0.4800 - val_loss: 1.0944 - val_categorical_accuracy: 0.4812
# Epoch 2/100
# 1/1 [==============================] - 0s 70ms/step - loss: 1.0944 - categorical_accuracy: 0.4840 - val_loss: 1.0941 - val_categorical_accuracy: 0.4894
# Epoch 3/100
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0941 - categorical_accuracy: 0.4960 - val_loss: 1.0938 - val_categorical_accuracy: 0.4962
# Epoch 4/100
# 1/1 [==============================] - 0s 67ms/step - loss: 1.0938 - categorical_accuracy: 0.5040 - val_loss: 1.0936 - val_categorical_accuracy: 0.5023
# Epoch 5/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0935 - categorical_accuracy: 0.5100 - val_loss: 1.0933 - val_categorical_accuracy: 0.5066
# Epoch 6/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0933 - categorical_accuracy: 0.5160 - val_loss: 1.0930 - val_categorical_accuracy: 0.5110
# Epoch 7/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.0930 - categorical_accuracy: 0.5180 - val_loss: 1.0927 - val_categorical_accuracy: 0.5150
# Epoch 8/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0927 - categorical_accuracy: 0.5240 - val_loss: 1.0925 - val_categorical_accuracy: 0.5186
# Epoch 9/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.0925 - categorical_accuracy: 0.5260 - val_loss: 1.0922 - val_categorical_accuracy: 0.5219
# Epoch 10/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.0922 - categorical_accuracy: 0.5340 - val_loss: 1.0919 - val_categorical_accuracy: 0.5244
# Epoch 11/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0919 - categorical_accuracy: 0.5320 - val_loss: 1.0917 - val_categorical_accuracy: 0.5269
# Epoch 12/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0916 - categorical_accuracy: 0.5320 - val_loss: 1.0914 - val_categorical_accuracy: 0.5297
# Epoch 13/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0914 - categorical_accuracy: 0.5380 - val_loss: 1.0912 - val_categorical_accuracy: 0.5313
# Epoch 14/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0911 - categorical_accuracy: 0.5420 - val_loss: 1.0909 - val_categorical_accuracy: 0.5331
# Epoch 15/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0909 - categorical_accuracy: 0.5380 - val_loss: 1.0907 - val_categorical_accuracy: 0.5359
# Epoch 16/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0906 - categorical_accuracy: 0.5380 - val_loss: 1.0904 - val_categorical_accuracy: 0.5392
# Epoch 17/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0904 - categorical_accuracy: 0.5320 - val_loss: 1.0901 - val_categorical_accuracy: 0.5418
# Epoch 18/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0901 - categorical_accuracy: 0.5320 - val_loss: 1.0899 - val_categorical_accuracy: 0.5445
# Epoch 19/100
# 1/1 [==============================] - 0s 64ms/step - loss: 1.0899 - categorical_accuracy: 0.5340 - val_loss: 1.0896 - val_categorical_accuracy: 0.5472
# Epoch 20/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0896 - categorical_accuracy: 0.5340 - val_loss: 1.0894 - val_categorical_accuracy: 0.5500
# Epoch 21/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0894 - categorical_accuracy: 0.5320 - val_loss: 1.0891 - val_categorical_accuracy: 0.5523
# Epoch 22/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0891 - categorical_accuracy: 0.5280 - val_loss: 1.0889 - val_categorical_accuracy: 0.5542
# Epoch 23/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.0889 - categorical_accuracy: 0.5320 - val_loss: 1.0887 - val_categorical_accuracy: 0.5557
# Epoch 24/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0886 - categorical_accuracy: 0.5300 - val_loss: 1.0884 - val_categorical_accuracy: 0.5570
# Epoch 25/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0884 - categorical_accuracy: 0.5400 - val_loss: 1.0882 - val_categorical_accuracy: 0.5581
# Epoch 26/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0881 - categorical_accuracy: 0.5440 - val_loss: 1.0879 - val_categorical_accuracy: 0.5596
# Epoch 27/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0879 - categorical_accuracy: 0.5420 - val_loss: 1.0877 - val_categorical_accuracy: 0.5605
# Epoch 28/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0876 - categorical_accuracy: 0.5440 - val_loss: 1.0874 - val_categorical_accuracy: 0.5614
# Epoch 29/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0874 - categorical_accuracy: 0.5440 - val_loss: 1.0872 - val_categorical_accuracy: 0.5621
# Epoch 30/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0871 - categorical_accuracy: 0.5440 - val_loss: 1.0869 - val_categorical_accuracy: 0.5629
# Epoch 31/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0869 - categorical_accuracy: 0.5440 - val_loss: 1.0867 - val_categorical_accuracy: 0.5633
# Epoch 32/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0866 - categorical_accuracy: 0.5480 - val_loss: 1.0864 - val_categorical_accuracy: 0.5637
# Epoch 33/100
# 1/1 [==============================] - 0s 49ms/step - loss: 1.0864 - categorical_accuracy: 0.5480 - val_loss: 1.0862 - val_categorical_accuracy: 0.5641
# Epoch 34/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0861 - categorical_accuracy: 0.5460 - val_loss: 1.0859 - val_categorical_accuracy: 0.5644
# Epoch 35/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0859 - categorical_accuracy: 0.5460 - val_loss: 1.0857 - val_categorical_accuracy: 0.5649
# Epoch 36/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0856 - categorical_accuracy: 0.5460 - val_loss: 1.0854 - val_categorical_accuracy: 0.5653
# Epoch 37/100
# 1/1 [==============================] - 0s 59ms/step - loss: 1.0854 - categorical_accuracy: 0.5420 - val_loss: 1.0852 - val_categorical_accuracy: 0.5651
# Epoch 38/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.0851 - categorical_accuracy: 0.5460 - val_loss: 1.0849 - val_categorical_accuracy: 0.5652
# Epoch 39/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.0849 - categorical_accuracy: 0.5460 - val_loss: 1.0846 - val_categorical_accuracy: 0.5656
# Epoch 40/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0846 - categorical_accuracy: 0.5460 - val_loss: 1.0844 - val_categorical_accuracy: 0.5659
# Epoch 41/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0844 - categorical_accuracy: 0.5440 - val_loss: 1.0841 - val_categorical_accuracy: 0.5658
# Epoch 42/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.0841 - categorical_accuracy: 0.5440 - val_loss: 1.0839 - val_categorical_accuracy: 0.5658
# Epoch 43/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0839 - categorical_accuracy: 0.5460 - val_loss: 1.0836 - val_categorical_accuracy: 0.5658
# Epoch 44/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.0836 - categorical_accuracy: 0.5460 - val_loss: 1.0833 - val_categorical_accuracy: 0.5660
# Epoch 45/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0833 - categorical_accuracy: 0.5460 - val_loss: 1.0830 - val_categorical_accuracy: 0.5660
# Epoch 46/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0831 - categorical_accuracy: 0.5460 - val_loss: 1.0828 - val_categorical_accuracy: 0.5660
# Epoch 47/100
# 1/1 [==============================] - 0s 49ms/step - loss: 1.0828 - categorical_accuracy: 0.5460 - val_loss: 1.0825 - val_categorical_accuracy: 0.5662
# Epoch 48/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0825 - categorical_accuracy: 0.5460 - val_loss: 1.0822 - val_categorical_accuracy: 0.5663
# Epoch 49/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0823 - categorical_accuracy: 0.5460 - val_loss: 1.0819 - val_categorical_accuracy: 0.5665
# Epoch 50/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.0820 - categorical_accuracy: 0.5460 - val_loss: 1.0817 - val_categorical_accuracy: 0.5666
# Epoch 51/100
# 1/1 [==============================] - 0s 59ms/step - loss: 1.0817 - categorical_accuracy: 0.5460 - val_loss: 1.0814 - val_categorical_accuracy: 0.5666
# Epoch 52/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0814 - categorical_accuracy: 0.5460 - val_loss: 1.0811 - val_categorical_accuracy: 0.5667
# Epoch 53/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0811 - categorical_accuracy: 0.5460 - val_loss: 1.0808 - val_categorical_accuracy: 0.5667
# Epoch 54/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0809 - categorical_accuracy: 0.5460 - val_loss: 1.0805 - val_categorical_accuracy: 0.5667
# Epoch 55/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0806 - categorical_accuracy: 0.5460 - val_loss: 1.0802 - val_categorical_accuracy: 0.5668
# Epoch 56/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0803 - categorical_accuracy: 0.5500 - val_loss: 1.0799 - val_categorical_accuracy: 0.5668
# Epoch 57/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0799 - categorical_accuracy: 0.5500 - val_loss: 1.0796 - val_categorical_accuracy: 0.5669
# Epoch 58/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0796 - categorical_accuracy: 0.5500 - val_loss: 1.0792 - val_categorical_accuracy: 0.5669
# Epoch 59/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0793 - categorical_accuracy: 0.5520 - val_loss: 1.0789 - val_categorical_accuracy: 0.5669
# Epoch 60/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0790 - categorical_accuracy: 0.5520 - val_loss: 1.0786 - val_categorical_accuracy: 0.5669
# Epoch 61/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0786 - categorical_accuracy: 0.5500 - val_loss: 1.0782 - val_categorical_accuracy: 0.5669
# Epoch 62/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0783 - categorical_accuracy: 0.5480 - val_loss: 1.0779 - val_categorical_accuracy: 0.5669
# Epoch 63/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0779 - categorical_accuracy: 0.5480 - val_loss: 1.0775 - val_categorical_accuracy: 0.5669
# Epoch 64/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0776 - categorical_accuracy: 0.5480 - val_loss: 1.0771 - val_categorical_accuracy: 0.5669
# Epoch 65/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0772 - categorical_accuracy: 0.5480 - val_loss: 1.0768 - val_categorical_accuracy: 0.5670
# Epoch 66/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0769 - categorical_accuracy: 0.5480 - val_loss: 1.0764 - val_categorical_accuracy: 0.5670
# Epoch 67/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0765 - categorical_accuracy: 0.5480 - val_loss: 1.0760 - val_categorical_accuracy: 0.5670
# Epoch 68/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0761 - categorical_accuracy: 0.5480 - val_loss: 1.0756 - val_categorical_accuracy: 0.5671
# Epoch 69/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0757 - categorical_accuracy: 0.5480 - val_loss: 1.0752 - val_categorical_accuracy: 0.5670
# Epoch 70/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0753 - categorical_accuracy: 0.5480 - val_loss: 1.0748 - val_categorical_accuracy: 0.5670
# Epoch 71/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0749 - categorical_accuracy: 0.5480 - val_loss: 1.0743 - val_categorical_accuracy: 0.5670
# Epoch 72/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0745 - categorical_accuracy: 0.5480 - val_loss: 1.0739 - val_categorical_accuracy: 0.5670
# Epoch 73/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0741 - categorical_accuracy: 0.5480 - val_loss: 1.0735 - val_categorical_accuracy: 0.5670
# Epoch 74/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0737 - categorical_accuracy: 0.5480 - val_loss: 1.0730 - val_categorical_accuracy: 0.5670
# Epoch 75/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0732 - categorical_accuracy: 0.5480 - val_loss: 1.0726 - val_categorical_accuracy: 0.5670
# Epoch 76/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0728 - categorical_accuracy: 0.5480 - val_loss: 1.0722 - val_categorical_accuracy: 0.5670
# Epoch 77/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0724 - categorical_accuracy: 0.5500 - val_loss: 1.0717 - val_categorical_accuracy: 0.5670
# Epoch 78/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0719 - categorical_accuracy: 0.5500 - val_loss: 1.0712 - val_categorical_accuracy: 0.5670
# Epoch 79/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0715 - categorical_accuracy: 0.5500 - val_loss: 1.0708 - val_categorical_accuracy: 0.5671
# Epoch 80/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0711 - categorical_accuracy: 0.5500 - val_loss: 1.0703 - val_categorical_accuracy: 0.5671
# Epoch 81/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0706 - categorical_accuracy: 0.5500 - val_loss: 1.0699 - val_categorical_accuracy: 0.5671
# Epoch 82/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0702 - categorical_accuracy: 0.5500 - val_loss: 1.0694 - val_categorical_accuracy: 0.5671
# Epoch 83/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0697 - categorical_accuracy: 0.5500 - val_loss: 1.0690 - val_categorical_accuracy: 0.5671
# Epoch 84/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0693 - categorical_accuracy: 0.5500 - val_loss: 1.0685 - val_categorical_accuracy: 0.5671
# Epoch 85/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0689 - categorical_accuracy: 0.5500 - val_loss: 1.0681 - val_categorical_accuracy: 0.5671
# Epoch 86/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0684 - categorical_accuracy: 0.5500 - val_loss: 1.0676 - val_categorical_accuracy: 0.5671
# Epoch 87/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0680 - categorical_accuracy: 0.5500 - val_loss: 1.0672 - val_categorical_accuracy: 0.5671
# Epoch 88/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0675 - categorical_accuracy: 0.5500 - val_loss: 1.0667 - val_categorical_accuracy: 0.5671
# Epoch 89/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0671 - categorical_accuracy: 0.5500 - val_loss: 1.0663 - val_categorical_accuracy: 0.5671
# Epoch 90/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0667 - categorical_accuracy: 0.5500 - val_loss: 1.0658 - val_categorical_accuracy: 0.5672
# Epoch 91/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0662 - categorical_accuracy: 0.5500 - val_loss: 1.0654 - val_categorical_accuracy: 0.5672
# Epoch 92/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0658 - categorical_accuracy: 0.5500 - val_loss: 1.0649 - val_categorical_accuracy: 0.5672
# Epoch 93/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0654 - categorical_accuracy: 0.5500 - val_loss: 1.0645 - val_categorical_accuracy: 0.5672
# Epoch 94/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0649 - categorical_accuracy: 0.5500 - val_loss: 1.0640 - val_categorical_accuracy: 0.5672
# Epoch 95/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0645 - categorical_accuracy: 0.5500 - val_loss: 1.0636 - val_categorical_accuracy: 0.5672
# Epoch 96/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0641 - categorical_accuracy: 0.5500 - val_loss: 1.0632 - val_categorical_accuracy: 0.5672
# Epoch 97/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0637 - categorical_accuracy: 0.5500 - val_loss: 1.0627 - val_categorical_accuracy: 0.5672
# Epoch 98/100
# 1/1 [==============================] - 0s 81ms/step - loss: 1.0633 - categorical_accuracy: 0.5500 - val_loss: 1.0623 - val_categorical_accuracy: 0.5672
# Epoch 99/100
# 1/1 [==============================] - 0s 99ms/step - loss: 1.0629 - categorical_accuracy: 0.5500 - val_loss: 1.0619 - val_categorical_accuracy: 0.5672
# Epoch 100/100
# 1/1 [==============================] - 0s 60ms/step - loss: 1.0624 - categorical_accuracy: 0.5500 - val_loss: 1.0615 - val_categorical_accuracy: 0.5672

# %% [markdown]
# ## Margin Sampling and Entropy Sampling:
# ### Margin: Go through unlabeled data and pick samples that the model has the smallest difference between first and second most probable class
# ### Entropy: Go through unlabeled data and pick samples that the model has the largest prob distribution difference from true

# %%
from scipy.stats import entropy
def update_training_data(model, X_train, y_train, X_u, y_u, new_data_size = 1000, method = "margin_sampling"):
    # Params:
    # model is currently trained model
    # X_train and y_train are current training data
    # X_u and y_u are current unlabeled data to select new training data from

    # returns:
    # new X_train, y_train, X_u, y_u 
    if method == "margin_sampling":
        preds = model.predict(X_u)
        margins = []
        for pred in preds:
            sorted = pred[np.argsort(pred)]
            margins.append(sorted[-1] - sorted[-2]) 

        margins = np.array(margins)

        selected_idxs = np.argpartition(margins, new_data_size)[:new_data_size]
        not_selected_idxs = np.array(list(set(range(len(X_u))) - set(selected_idxs)))

        X_train = np.concatenate((X_train, X_u[selected_idxs]), axis = 0)
        y_train = np.concatenate((y_train, y_u[selected_idxs]), axis = 0)
        X_u = X_u[not_selected_idxs]
        y_u = y_u[not_selected_idxs]
    

        return X_train, y_train, X_u, y_u

    elif method == "random_sampling":
        perm = np.random.permutation(len(X_u))
        X_u = X_u[perm]
        y_u = y_u[perm]
        selected_idxs = np.array(list(range(0,new_data_size)))
        not_selected_idxs = np.array(list(range(new_data_size,len(X_u))))

        X_train = np.concatenate((X_train, X_u[selected_idxs]), axis = 0)
        y_train = np.concatenate((y_train, y_u[selected_idxs]), axis = 0)
        X_u = X_u[not_selected_idxs]
        y_u = y_u[not_selected_idxs]
    

        return X_train, y_train, X_u, y_u



    elif method == "entropy_sampling":
        preds = model.predict(X_u)
        entrops = []
        for idx, pred in enumerate(preds):
            entrop = stats.entropy(pred, y_u[idx])
            entrops.append(entrop)

        entrops = np.array(entrops)

        selected_idxs = np.argpartition(entrops, -new_data_size)[-new_data_size:]
        not_selected_idxs = np.array(list(set(range(len(X_u))) - set(selected_idxs)))

        X_train = np.concatenate((X_train, X_u[selected_idxs]), axis = 0)
        y_train = np.concatenate((y_train, y_u[selected_idxs]), axis = 0)
        X_u = X_u[not_selected_idxs]
        y_u = y_u[not_selected_idxs]
    

        return X_train, y_train, X_u, y_u

    else:
        raise NotImplementedError("The method {} has not been implemented".format(method))

# %% [markdown]
# ## Run margin sampling
#
# ### We see that it can train a model that reaches .675 accuracy with only 9000 datapoints. Training the same model on 9000 randomly selected datapoints only achieves around 0.57 accuracy

# %%
import time
val_accs = []
while history.history["val_categorical_accuracy"][-1] < .675:
    X_train, y_train, X_u, y_u = update_training_data(model, X_train, y_train, X_u, y_u, new_data_size = 500, method = "margin_sampling")
    model.reset_states()
    history = model.fit(X_train, y_train, epochs=100, batch_size=batch_size, validation_data=(X_val, y_val), callbacks=[model_checkpoint_callback])
    print("Trained on {} unique samples total".format(len(X_train)))
    val_acc = history.history["val_categorical_accuracy"][-1]
    print("New val accuracy is {}".format(val_acc))
    val_accs.append(val_acc)
    time.sleep(3)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 76ms/step - loss: 1.0747 - categorical_accuracy: 0.5110 - val_loss: 1.0738 - val_categorical_accuracy: 0.5487
# Epoch 2/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0744 - categorical_accuracy: 0.5510 - val_loss: 1.0735 - val_categorical_accuracy: 0.5485
# Epoch 3/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0741 - categorical_accuracy: 0.5490 - val_loss: 1.0731 - val_categorical_accuracy: 0.5478
# Epoch 4/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0737 - categorical_accuracy: 0.5490 - val_loss: 1.0728 - val_categorical_accuracy: 0.5477
# Epoch 5/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0734 - categorical_accuracy: 0.5480 - val_loss: 1.0724 - val_categorical_accuracy: 0.5476
# Epoch 6/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0730 - categorical_accuracy: 0.5490 - val_loss: 1.0721 - val_categorical_accuracy: 0.5481
# Epoch 7/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0727 - categorical_accuracy: 0.5490 - val_loss: 1.0718 - val_categorical_accuracy: 0.5483
# Epoch 8/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0723 - categorical_accuracy: 0.5480 - val_loss: 1.0714 - val_categorical_accuracy: 0.5475
# Epoch 9/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0720 - categorical_accuracy: 0.5470 - val_loss: 1.0711 - val_categorical_accuracy: 0.5474
# Epoch 10/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0716 - categorical_accuracy: 0.5470 - val_loss: 1.0707 - val_categorical_accuracy: 0.5471
# Epoch 11/100
# 1/1 [==============================] - 0s 49ms/step - loss: 1.0712 - categorical_accuracy: 0.5460 - val_loss: 1.0703 - val_categorical_accuracy: 0.5467
# Epoch 12/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0709 - categorical_accuracy: 0.5440 - val_loss: 1.0700 - val_categorical_accuracy: 0.5466
# Epoch 13/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0705 - categorical_accuracy: 0.5450 - val_loss: 1.0696 - val_categorical_accuracy: 0.5464
# Epoch 14/100
# 1/1 [==============================] - 0s 49ms/step - loss: 1.0701 - categorical_accuracy: 0.5460 - val_loss: 1.0693 - val_categorical_accuracy: 0.5463
# Epoch 15/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0698 - categorical_accuracy: 0.5440 - val_loss: 1.0689 - val_categorical_accuracy: 0.5465
# Epoch 16/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0694 - categorical_accuracy: 0.5420 - val_loss: 1.0686 - val_categorical_accuracy: 0.5464
# Epoch 17/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0690 - categorical_accuracy: 0.5420 - val_loss: 1.0682 - val_categorical_accuracy: 0.5466
# Epoch 18/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0686 - categorical_accuracy: 0.5420 - val_loss: 1.0678 - val_categorical_accuracy: 0.5465
# Epoch 19/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0683 - categorical_accuracy: 0.5400 - val_loss: 1.0674 - val_categorical_accuracy: 0.5472
# Epoch 20/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0679 - categorical_accuracy: 0.5420 - val_loss: 1.0671 - val_categorical_accuracy: 0.5476
# Epoch 21/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0675 - categorical_accuracy: 0.5420 - val_loss: 1.0667 - val_categorical_accuracy: 0.5474
# Epoch 22/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0671 - categorical_accuracy: 0.5440 - val_loss: 1.0663 - val_categorical_accuracy: 0.5477
# Epoch 23/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0667 - categorical_accuracy: 0.5400 - val_loss: 1.0659 - val_categorical_accuracy: 0.5475
# Epoch 24/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0663 - categorical_accuracy: 0.5410 - val_loss: 1.0656 - val_categorical_accuracy: 0.5474
# Epoch 25/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0659 - categorical_accuracy: 0.5430 - val_loss: 1.0652 - val_categorical_accuracy: 0.5476
# Epoch 26/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0655 - categorical_accuracy: 0.5410 - val_loss: 1.0648 - val_categorical_accuracy: 0.5478
# Epoch 27/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0651 - categorical_accuracy: 0.5390 - val_loss: 1.0644 - val_categorical_accuracy: 0.5483
# Epoch 28/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0647 - categorical_accuracy: 0.5410 - val_loss: 1.0640 - val_categorical_accuracy: 0.5490
# Epoch 29/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0643 - categorical_accuracy: 0.5400 - val_loss: 1.0636 - val_categorical_accuracy: 0.5499
# Epoch 30/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0639 - categorical_accuracy: 0.5400 - val_loss: 1.0632 - val_categorical_accuracy: 0.5505
# Epoch 31/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0634 - categorical_accuracy: 0.5390 - val_loss: 1.0628 - val_categorical_accuracy: 0.5510
# Epoch 32/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0630 - categorical_accuracy: 0.5390 - val_loss: 1.0624 - val_categorical_accuracy: 0.5514
# Epoch 33/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0626 - categorical_accuracy: 0.5390 - val_loss: 1.0620 - val_categorical_accuracy: 0.5520
# Epoch 34/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0622 - categorical_accuracy: 0.5390 - val_loss: 1.0616 - val_categorical_accuracy: 0.5527
# Epoch 35/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0618 - categorical_accuracy: 0.5380 - val_loss: 1.0612 - val_categorical_accuracy: 0.5536
# Epoch 36/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0613 - categorical_accuracy: 0.5370 - val_loss: 1.0608 - val_categorical_accuracy: 0.5539
# Epoch 37/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0609 - categorical_accuracy: 0.5380 - val_loss: 1.0604 - val_categorical_accuracy: 0.5543
# Epoch 38/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0605 - categorical_accuracy: 0.5390 - val_loss: 1.0600 - val_categorical_accuracy: 0.5545
# Epoch 39/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0600 - categorical_accuracy: 0.5390 - val_loss: 1.0596 - val_categorical_accuracy: 0.5547
# Epoch 40/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0596 - categorical_accuracy: 0.5390 - val_loss: 1.0592 - val_categorical_accuracy: 0.5551
# Epoch 41/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0592 - categorical_accuracy: 0.5390 - val_loss: 1.0587 - val_categorical_accuracy: 0.5553
# Epoch 42/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0587 - categorical_accuracy: 0.5390 - val_loss: 1.0583 - val_categorical_accuracy: 0.5557
# Epoch 43/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0583 - categorical_accuracy: 0.5400 - val_loss: 1.0579 - val_categorical_accuracy: 0.5556
# Epoch 44/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0578 - categorical_accuracy: 0.5390 - val_loss: 1.0575 - val_categorical_accuracy: 0.5557
# Epoch 45/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0574 - categorical_accuracy: 0.5360 - val_loss: 1.0570 - val_categorical_accuracy: 0.5558
# Epoch 46/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0569 - categorical_accuracy: 0.5360 - val_loss: 1.0566 - val_categorical_accuracy: 0.5559
# Epoch 47/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0565 - categorical_accuracy: 0.5360 - val_loss: 1.0562 - val_categorical_accuracy: 0.5558
# Epoch 48/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0560 - categorical_accuracy: 0.5360 - val_loss: 1.0558 - val_categorical_accuracy: 0.5561
# Epoch 49/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0556 - categorical_accuracy: 0.5360 - val_loss: 1.0553 - val_categorical_accuracy: 0.5562
# Epoch 50/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0551 - categorical_accuracy: 0.5360 - val_loss: 1.0549 - val_categorical_accuracy: 0.5564
# Epoch 51/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0547 - categorical_accuracy: 0.5360 - val_loss: 1.0545 - val_categorical_accuracy: 0.5564
# Epoch 52/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0542 - categorical_accuracy: 0.5370 - val_loss: 1.0540 - val_categorical_accuracy: 0.5564
# Epoch 53/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0538 - categorical_accuracy: 0.5370 - val_loss: 1.0536 - val_categorical_accuracy: 0.5564
# Epoch 54/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0533 - categorical_accuracy: 0.5370 - val_loss: 1.0532 - val_categorical_accuracy: 0.5566
# Epoch 55/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0528 - categorical_accuracy: 0.5370 - val_loss: 1.0527 - val_categorical_accuracy: 0.5566
# Epoch 56/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0524 - categorical_accuracy: 0.5370 - val_loss: 1.0523 - val_categorical_accuracy: 0.5567
# Epoch 57/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0519 - categorical_accuracy: 0.5370 - val_loss: 1.0519 - val_categorical_accuracy: 0.5572
# Epoch 58/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0515 - categorical_accuracy: 0.5370 - val_loss: 1.0514 - val_categorical_accuracy: 0.5573
# Epoch 59/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0510 - categorical_accuracy: 0.5370 - val_loss: 1.0510 - val_categorical_accuracy: 0.5575
# Epoch 60/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0506 - categorical_accuracy: 0.5370 - val_loss: 1.0505 - val_categorical_accuracy: 0.5577
# Epoch 61/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0501 - categorical_accuracy: 0.5370 - val_loss: 1.0501 - val_categorical_accuracy: 0.5578
# Epoch 62/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0497 - categorical_accuracy: 0.5370 - val_loss: 1.0497 - val_categorical_accuracy: 0.5578
# Epoch 63/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0492 - categorical_accuracy: 0.5370 - val_loss: 1.0492 - val_categorical_accuracy: 0.5583
# Epoch 64/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0487 - categorical_accuracy: 0.5370 - val_loss: 1.0488 - val_categorical_accuracy: 0.5589
# Epoch 65/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0483 - categorical_accuracy: 0.5370 - val_loss: 1.0483 - val_categorical_accuracy: 0.5591
# Epoch 66/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0478 - categorical_accuracy: 0.5370 - val_loss: 1.0479 - val_categorical_accuracy: 0.5593
# Epoch 67/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0474 - categorical_accuracy: 0.5370 - val_loss: 1.0474 - val_categorical_accuracy: 0.5595
# Epoch 68/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0469 - categorical_accuracy: 0.5370 - val_loss: 1.0470 - val_categorical_accuracy: 0.5597
# Epoch 69/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0465 - categorical_accuracy: 0.5370 - val_loss: 1.0466 - val_categorical_accuracy: 0.5598
# Epoch 70/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0460 - categorical_accuracy: 0.5370 - val_loss: 1.0461 - val_categorical_accuracy: 0.5603
# Epoch 71/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0455 - categorical_accuracy: 0.5370 - val_loss: 1.0457 - val_categorical_accuracy: 0.5605
# Epoch 72/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0451 - categorical_accuracy: 0.5370 - val_loss: 1.0452 - val_categorical_accuracy: 0.5604
# Epoch 73/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0446 - categorical_accuracy: 0.5370 - val_loss: 1.0448 - val_categorical_accuracy: 0.5606
# Epoch 74/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0441 - categorical_accuracy: 0.5370 - val_loss: 1.0443 - val_categorical_accuracy: 0.5607
# Epoch 75/100
# 1/1 [==============================] - 0s 52ms/step - loss: 1.0437 - categorical_accuracy: 0.5370 - val_loss: 1.0439 - val_categorical_accuracy: 0.5609
# Epoch 76/100
# 1/1 [==============================] - 0s 56ms/step - loss: 1.0432 - categorical_accuracy: 0.5370 - val_loss: 1.0434 - val_categorical_accuracy: 0.5609
# Epoch 77/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0428 - categorical_accuracy: 0.5370 - val_loss: 1.0430 - val_categorical_accuracy: 0.5611
# Epoch 78/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.0423 - categorical_accuracy: 0.5370 - val_loss: 1.0425 - val_categorical_accuracy: 0.5613
# Epoch 79/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0418 - categorical_accuracy: 0.5380 - val_loss: 1.0421 - val_categorical_accuracy: 0.5614
# Epoch 80/100
# 1/1 [==============================] - 0s 53ms/step - loss: 1.0414 - categorical_accuracy: 0.5380 - val_loss: 1.0416 - val_categorical_accuracy: 0.5615
# Epoch 81/100
# 1/1 [==============================] - 0s 59ms/step - loss: 1.0409 - categorical_accuracy: 0.5380 - val_loss: 1.0412 - val_categorical_accuracy: 0.5616
# Epoch 82/100
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0404 - categorical_accuracy: 0.5380 - val_loss: 1.0407 - val_categorical_accuracy: 0.5618
# Epoch 83/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0400 - categorical_accuracy: 0.5380 - val_loss: 1.0403 - val_categorical_accuracy: 0.5619
# Epoch 84/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0395 - categorical_accuracy: 0.5380 - val_loss: 1.0398 - val_categorical_accuracy: 0.5620
# Epoch 85/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0390 - categorical_accuracy: 0.5380 - val_loss: 1.0394 - val_categorical_accuracy: 0.5622
# Epoch 86/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0385 - categorical_accuracy: 0.5380 - val_loss: 1.0389 - val_categorical_accuracy: 0.5622
# Epoch 87/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0381 - categorical_accuracy: 0.5380 - val_loss: 1.0384 - val_categorical_accuracy: 0.5622
# Epoch 88/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0376 - categorical_accuracy: 0.5380 - val_loss: 1.0380 - val_categorical_accuracy: 0.5624
# Epoch 89/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0371 - categorical_accuracy: 0.5380 - val_loss: 1.0375 - val_categorical_accuracy: 0.5625
# Epoch 90/100
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0366 - categorical_accuracy: 0.5380 - val_loss: 1.0371 - val_categorical_accuracy: 0.5626
# Epoch 91/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0362 - categorical_accuracy: 0.5380 - val_loss: 1.0366 - val_categorical_accuracy: 0.5627
# Epoch 92/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0357 - categorical_accuracy: 0.5380 - val_loss: 1.0361 - val_categorical_accuracy: 0.5629
# Epoch 93/100
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0352 - categorical_accuracy: 0.5380 - val_loss: 1.0357 - val_categorical_accuracy: 0.5630
# Epoch 94/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0347 - categorical_accuracy: 0.5380 - val_loss: 1.0352 - val_categorical_accuracy: 0.5632
# Epoch 95/100
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0342 - categorical_accuracy: 0.5380 - val_loss: 1.0347 - val_categorical_accuracy: 0.5632
# Epoch 96/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0338 - categorical_accuracy: 0.5380 - val_loss: 1.0343 - val_categorical_accuracy: 0.5634
# Epoch 97/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0333 - categorical_accuracy: 0.5380 - val_loss: 1.0338 - val_categorical_accuracy: 0.5637
# Epoch 98/100
# 1/1 [==============================] - 0s 57ms/step - loss: 1.0328 - categorical_accuracy: 0.5380 - val_loss: 1.0333 - val_categorical_accuracy: 0.5638
# Epoch 99/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0323 - categorical_accuracy: 0.5380 - val_loss: 1.0329 - val_categorical_accuracy: 0.5639
# Epoch 100/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0318 - categorical_accuracy: 0.5390 - val_loss: 1.0324 - val_categorical_accuracy: 0.5641
# Trained on 1000 unique samples total
# New val accuracy is 0.5640572905540466
# Epoch 1/100
# 1/1 [==============================] - 0s 69ms/step - loss: 1.0363 - categorical_accuracy: 0.5060 - val_loss: 1.0319 - val_categorical_accuracy: 0.5641
# Epoch 2/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0357 - categorical_accuracy: 0.5153 - val_loss: 1.0315 - val_categorical_accuracy: 0.5643
# Epoch 3/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0352 - categorical_accuracy: 0.5360 - val_loss: 1.0310 - val_categorical_accuracy: 0.5646
# Epoch 4/100
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0347 - categorical_accuracy: 0.5553 - val_loss: 1.0305 - val_categorical_accuracy: 0.5647
# Epoch 5/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0342 - categorical_accuracy: 0.5600 - val_loss: 1.0300 - val_categorical_accuracy: 0.5647
# Epoch 6/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0336 - categorical_accuracy: 0.5600 - val_loss: 1.0296 - val_categorical_accuracy: 0.5649
# Epoch 7/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0331 - categorical_accuracy: 0.5613 - val_loss: 1.0291 - val_categorical_accuracy: 0.5652
# Epoch 8/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0325 - categorical_accuracy: 0.5620 - val_loss: 1.0286 - val_categorical_accuracy: 0.5654
# Epoch 9/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0319 - categorical_accuracy: 0.5620 - val_loss: 1.0281 - val_categorical_accuracy: 0.5656
# Epoch 10/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0314 - categorical_accuracy: 0.5620 - val_loss: 1.0276 - val_categorical_accuracy: 0.5657
# Epoch 11/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0308 - categorical_accuracy: 0.5620 - val_loss: 1.0272 - val_categorical_accuracy: 0.5658
# Epoch 12/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0302 - categorical_accuracy: 0.5627 - val_loss: 1.0267 - val_categorical_accuracy: 0.5659
# Epoch 13/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0296 - categorical_accuracy: 0.5627 - val_loss: 1.0262 - val_categorical_accuracy: 0.5660
# Epoch 14/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0291 - categorical_accuracy: 0.5627 - val_loss: 1.0257 - val_categorical_accuracy: 0.5661
# Epoch 15/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0285 - categorical_accuracy: 0.5627 - val_loss: 1.0253 - val_categorical_accuracy: 0.5662
# Epoch 16/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0279 - categorical_accuracy: 0.5627 - val_loss: 1.0248 - val_categorical_accuracy: 0.5663
# Epoch 17/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0273 - categorical_accuracy: 0.5627 - val_loss: 1.0243 - val_categorical_accuracy: 0.5664
# Epoch 18/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0267 - categorical_accuracy: 0.5627 - val_loss: 1.0238 - val_categorical_accuracy: 0.5664
# Epoch 19/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0262 - categorical_accuracy: 0.5627 - val_loss: 1.0233 - val_categorical_accuracy: 0.5665
# Epoch 20/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0256 - categorical_accuracy: 0.5627 - val_loss: 1.0229 - val_categorical_accuracy: 0.5666
# Epoch 21/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0250 - categorical_accuracy: 0.5627 - val_loss: 1.0224 - val_categorical_accuracy: 0.5666
# Epoch 22/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0244 - categorical_accuracy: 0.5627 - val_loss: 1.0219 - val_categorical_accuracy: 0.5666
# Epoch 23/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0238 - categorical_accuracy: 0.5627 - val_loss: 1.0214 - val_categorical_accuracy: 0.5667
# Epoch 24/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0233 - categorical_accuracy: 0.5627 - val_loss: 1.0210 - val_categorical_accuracy: 0.5667
# Epoch 25/100
# 1/1 [==============================] - 0s 49ms/step - loss: 1.0227 - categorical_accuracy: 0.5633 - val_loss: 1.0205 - val_categorical_accuracy: 0.5668
# Epoch 26/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0221 - categorical_accuracy: 0.5633 - val_loss: 1.0200 - val_categorical_accuracy: 0.5668
# Epoch 27/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0215 - categorical_accuracy: 0.5633 - val_loss: 1.0195 - val_categorical_accuracy: 0.5668
# Epoch 28/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0209 - categorical_accuracy: 0.5633 - val_loss: 1.0190 - val_categorical_accuracy: 0.5668
# Epoch 29/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0203 - categorical_accuracy: 0.5633 - val_loss: 1.0186 - val_categorical_accuracy: 0.5669
# Epoch 30/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0198 - categorical_accuracy: 0.5633 - val_loss: 1.0181 - val_categorical_accuracy: 0.5670
# Epoch 31/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0192 - categorical_accuracy: 0.5633 - val_loss: 1.0176 - val_categorical_accuracy: 0.5670
# Epoch 32/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0186 - categorical_accuracy: 0.5633 - val_loss: 1.0171 - val_categorical_accuracy: 0.5670
# Epoch 33/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0180 - categorical_accuracy: 0.5633 - val_loss: 1.0166 - val_categorical_accuracy: 0.5671
# Epoch 34/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0174 - categorical_accuracy: 0.5633 - val_loss: 1.0161 - val_categorical_accuracy: 0.5671
# Epoch 35/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0168 - categorical_accuracy: 0.5633 - val_loss: 1.0157 - val_categorical_accuracy: 0.5671
# Epoch 36/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0162 - categorical_accuracy: 0.5633 - val_loss: 1.0152 - val_categorical_accuracy: 0.5671
# Epoch 37/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0157 - categorical_accuracy: 0.5633 - val_loss: 1.0147 - val_categorical_accuracy: 0.5671
# Epoch 38/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0151 - categorical_accuracy: 0.5633 - val_loss: 1.0142 - val_categorical_accuracy: 0.5671
# Epoch 39/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0145 - categorical_accuracy: 0.5633 - val_loss: 1.0137 - val_categorical_accuracy: 0.5671
# Epoch 40/100
# 1/1 [==============================] - 0s 107ms/step - loss: 1.0139 - categorical_accuracy: 0.5633 - val_loss: 1.0132 - val_categorical_accuracy: 0.5671
# Epoch 41/100
# 1/1 [==============================] - 0s 80ms/step - loss: 1.0133 - categorical_accuracy: 0.5633 - val_loss: 1.0127 - val_categorical_accuracy: 0.5671
# Epoch 42/100
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0127 - categorical_accuracy: 0.5633 - val_loss: 1.0122 - val_categorical_accuracy: 0.5671
# Epoch 43/100
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0122 - categorical_accuracy: 0.5633 - val_loss: 1.0118 - val_categorical_accuracy: 0.5671
# Epoch 44/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0116 - categorical_accuracy: 0.5633 - val_loss: 1.0113 - val_categorical_accuracy: 0.5671
# Epoch 45/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0110 - categorical_accuracy: 0.5633 - val_loss: 1.0108 - val_categorical_accuracy: 0.5671
# Epoch 46/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0104 - categorical_accuracy: 0.5633 - val_loss: 1.0103 - val_categorical_accuracy: 0.5671
# Epoch 47/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0098 - categorical_accuracy: 0.5633 - val_loss: 1.0098 - val_categorical_accuracy: 0.5671
# Epoch 48/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0092 - categorical_accuracy: 0.5633 - val_loss: 1.0093 - val_categorical_accuracy: 0.5671
# Epoch 49/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0087 - categorical_accuracy: 0.5633 - val_loss: 1.0088 - val_categorical_accuracy: 0.5671
# Epoch 50/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0081 - categorical_accuracy: 0.5633 - val_loss: 1.0083 - val_categorical_accuracy: 0.5672
# Epoch 51/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0075 - categorical_accuracy: 0.5633 - val_loss: 1.0078 - val_categorical_accuracy: 0.5672
# Epoch 52/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0069 - categorical_accuracy: 0.5633 - val_loss: 1.0073 - val_categorical_accuracy: 0.5672
# Epoch 53/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0063 - categorical_accuracy: 0.5633 - val_loss: 1.0068 - val_categorical_accuracy: 0.5672
# Epoch 54/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0058 - categorical_accuracy: 0.5633 - val_loss: 1.0064 - val_categorical_accuracy: 0.5672
# Epoch 55/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0052 - categorical_accuracy: 0.5633 - val_loss: 1.0059 - val_categorical_accuracy: 0.5672
# Epoch 56/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0046 - categorical_accuracy: 0.5633 - val_loss: 1.0054 - val_categorical_accuracy: 0.5672
# Epoch 57/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0040 - categorical_accuracy: 0.5633 - val_loss: 1.0049 - val_categorical_accuracy: 0.5672
# Epoch 58/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0034 - categorical_accuracy: 0.5633 - val_loss: 1.0044 - val_categorical_accuracy: 0.5672
# Epoch 59/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0029 - categorical_accuracy: 0.5633 - val_loss: 1.0039 - val_categorical_accuracy: 0.5672
# Epoch 60/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0023 - categorical_accuracy: 0.5633 - val_loss: 1.0034 - val_categorical_accuracy: 0.5672
# Epoch 61/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0017 - categorical_accuracy: 0.5633 - val_loss: 1.0029 - val_categorical_accuracy: 0.5672
# Epoch 62/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0011 - categorical_accuracy: 0.5633 - val_loss: 1.0024 - val_categorical_accuracy: 0.5672
# Epoch 63/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0006 - categorical_accuracy: 0.5633 - val_loss: 1.0019 - val_categorical_accuracy: 0.5672
# Epoch 64/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0000 - categorical_accuracy: 0.5633 - val_loss: 1.0014 - val_categorical_accuracy: 0.5672
# Epoch 65/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9994 - categorical_accuracy: 0.5633 - val_loss: 1.0009 - val_categorical_accuracy: 0.5672
# Epoch 66/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9988 - categorical_accuracy: 0.5633 - val_loss: 1.0004 - val_categorical_accuracy: 0.5672
# Epoch 67/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9983 - categorical_accuracy: 0.5633 - val_loss: 0.9999 - val_categorical_accuracy: 0.5672
# Epoch 68/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9977 - categorical_accuracy: 0.5633 - val_loss: 0.9994 - val_categorical_accuracy: 0.5672
# Epoch 69/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9971 - categorical_accuracy: 0.5633 - val_loss: 0.9989 - val_categorical_accuracy: 0.5672
# Epoch 70/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9965 - categorical_accuracy: 0.5633 - val_loss: 0.9984 - val_categorical_accuracy: 0.5672
# Epoch 71/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9960 - categorical_accuracy: 0.5633 - val_loss: 0.9979 - val_categorical_accuracy: 0.5672
# Epoch 72/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9954 - categorical_accuracy: 0.5633 - val_loss: 0.9974 - val_categorical_accuracy: 0.5672
# Epoch 73/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9948 - categorical_accuracy: 0.5633 - val_loss: 0.9969 - val_categorical_accuracy: 0.5672
# Epoch 74/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9942 - categorical_accuracy: 0.5633 - val_loss: 0.9964 - val_categorical_accuracy: 0.5672
# Epoch 75/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9937 - categorical_accuracy: 0.5633 - val_loss: 0.9959 - val_categorical_accuracy: 0.5672
# Epoch 76/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9931 - categorical_accuracy: 0.5633 - val_loss: 0.9954 - val_categorical_accuracy: 0.5672
# Epoch 77/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9925 - categorical_accuracy: 0.5633 - val_loss: 0.9949 - val_categorical_accuracy: 0.5672
# Epoch 78/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9919 - categorical_accuracy: 0.5633 - val_loss: 0.9944 - val_categorical_accuracy: 0.5672
# Epoch 79/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9913 - categorical_accuracy: 0.5633 - val_loss: 0.9939 - val_categorical_accuracy: 0.5672
# Epoch 80/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9908 - categorical_accuracy: 0.5633 - val_loss: 0.9934 - val_categorical_accuracy: 0.5672
# Epoch 81/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9902 - categorical_accuracy: 0.5633 - val_loss: 0.9929 - val_categorical_accuracy: 0.5672
# Epoch 82/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9896 - categorical_accuracy: 0.5633 - val_loss: 0.9924 - val_categorical_accuracy: 0.5672
# Epoch 83/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9891 - categorical_accuracy: 0.5633 - val_loss: 0.9919 - val_categorical_accuracy: 0.5672
# Epoch 84/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9885 - categorical_accuracy: 0.5633 - val_loss: 0.9914 - val_categorical_accuracy: 0.5672
# Epoch 85/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9879 - categorical_accuracy: 0.5633 - val_loss: 0.9909 - val_categorical_accuracy: 0.5672
# Epoch 86/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9873 - categorical_accuracy: 0.5633 - val_loss: 0.9904 - val_categorical_accuracy: 0.5672
# Epoch 87/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9868 - categorical_accuracy: 0.5633 - val_loss: 0.9899 - val_categorical_accuracy: 0.5672
# Epoch 88/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9862 - categorical_accuracy: 0.5633 - val_loss: 0.9894 - val_categorical_accuracy: 0.5672
# Epoch 89/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9856 - categorical_accuracy: 0.5633 - val_loss: 0.9889 - val_categorical_accuracy: 0.5672
# Epoch 90/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9850 - categorical_accuracy: 0.5633 - val_loss: 0.9884 - val_categorical_accuracy: 0.5672
# Epoch 91/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9845 - categorical_accuracy: 0.5633 - val_loss: 0.9879 - val_categorical_accuracy: 0.5672
# Epoch 92/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9839 - categorical_accuracy: 0.5633 - val_loss: 0.9874 - val_categorical_accuracy: 0.5672
# Epoch 93/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9833 - categorical_accuracy: 0.5633 - val_loss: 0.9869 - val_categorical_accuracy: 0.5672
# Epoch 94/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9827 - categorical_accuracy: 0.5633 - val_loss: 0.9864 - val_categorical_accuracy: 0.5672
# Epoch 95/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9822 - categorical_accuracy: 0.5633 - val_loss: 0.9859 - val_categorical_accuracy: 0.5672
# Epoch 96/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9816 - categorical_accuracy: 0.5633 - val_loss: 0.9854 - val_categorical_accuracy: 0.5672
# Epoch 97/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9810 - categorical_accuracy: 0.5633 - val_loss: 0.9849 - val_categorical_accuracy: 0.5672
# Epoch 98/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9805 - categorical_accuracy: 0.5633 - val_loss: 0.9844 - val_categorical_accuracy: 0.5672
# Epoch 99/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9799 - categorical_accuracy: 0.5633 - val_loss: 0.9839 - val_categorical_accuracy: 0.5672
# Epoch 100/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9793 - categorical_accuracy: 0.5633 - val_loss: 0.9834 - val_categorical_accuracy: 0.5672
# Trained on 1500 unique samples total
# New val accuracy is 0.567152738571167
# Epoch 1/100
# 1/1 [==============================] - 0s 91ms/step - loss: 1.0185 - categorical_accuracy: 0.5285 - val_loss: 0.9830 - val_categorical_accuracy: 0.5672
# Epoch 2/100
# 1/1 [==============================] - 0s 59ms/step - loss: 1.0181 - categorical_accuracy: 0.5285 - val_loss: 0.9825 - val_categorical_accuracy: 0.5672
# Epoch 3/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0176 - categorical_accuracy: 0.5285 - val_loss: 0.9821 - val_categorical_accuracy: 0.5672
# Epoch 4/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0172 - categorical_accuracy: 0.5285 - val_loss: 0.9817 - val_categorical_accuracy: 0.5672
# Epoch 5/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0167 - categorical_accuracy: 0.5285 - val_loss: 0.9813 - val_categorical_accuracy: 0.5672
# Epoch 6/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0163 - categorical_accuracy: 0.5285 - val_loss: 0.9809 - val_categorical_accuracy: 0.5672
# Epoch 7/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0158 - categorical_accuracy: 0.5285 - val_loss: 0.9805 - val_categorical_accuracy: 0.5672
# Epoch 8/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0154 - categorical_accuracy: 0.5285 - val_loss: 0.9802 - val_categorical_accuracy: 0.5672
# Epoch 9/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0149 - categorical_accuracy: 0.5285 - val_loss: 0.9798 - val_categorical_accuracy: 0.5672
# Epoch 10/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0145 - categorical_accuracy: 0.5285 - val_loss: 0.9795 - val_categorical_accuracy: 0.5672
# Epoch 11/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0140 - categorical_accuracy: 0.5285 - val_loss: 0.9792 - val_categorical_accuracy: 0.5672
# Epoch 12/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0136 - categorical_accuracy: 0.5285 - val_loss: 0.9789 - val_categorical_accuracy: 0.5672
# Epoch 13/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0131 - categorical_accuracy: 0.5285 - val_loss: 0.9786 - val_categorical_accuracy: 0.5672
# Epoch 14/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0127 - categorical_accuracy: 0.5285 - val_loss: 0.9783 - val_categorical_accuracy: 0.5672
# Epoch 15/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0122 - categorical_accuracy: 0.5285 - val_loss: 0.9780 - val_categorical_accuracy: 0.5672
# Epoch 16/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0117 - categorical_accuracy: 0.5285 - val_loss: 0.9777 - val_categorical_accuracy: 0.5672
# Epoch 17/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0113 - categorical_accuracy: 0.5285 - val_loss: 0.9774 - val_categorical_accuracy: 0.5672
# Epoch 18/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0108 - categorical_accuracy: 0.5285 - val_loss: 0.9771 - val_categorical_accuracy: 0.5672
# Epoch 19/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0103 - categorical_accuracy: 0.5285 - val_loss: 0.9768 - val_categorical_accuracy: 0.5672
# Epoch 20/100
# 1/1 [==============================] - 0s 91ms/step - loss: 1.0099 - categorical_accuracy: 0.5285 - val_loss: 0.9765 - val_categorical_accuracy: 0.5672
# Epoch 21/100
# 1/1 [==============================] - 0s 56ms/step - loss: 1.0094 - categorical_accuracy: 0.5285 - val_loss: 0.9762 - val_categorical_accuracy: 0.5672
# Epoch 22/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0089 - categorical_accuracy: 0.5285 - val_loss: 0.9759 - val_categorical_accuracy: 0.5672
# Epoch 23/100
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0085 - categorical_accuracy: 0.5285 - val_loss: 0.9756 - val_categorical_accuracy: 0.5672
# Epoch 24/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0080 - categorical_accuracy: 0.5285 - val_loss: 0.9753 - val_categorical_accuracy: 0.5672
# Epoch 25/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0075 - categorical_accuracy: 0.5285 - val_loss: 0.9750 - val_categorical_accuracy: 0.5672
# Epoch 26/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0071 - categorical_accuracy: 0.5285 - val_loss: 0.9747 - val_categorical_accuracy: 0.5672
# Epoch 27/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0066 - categorical_accuracy: 0.5285 - val_loss: 0.9744 - val_categorical_accuracy: 0.5672
# Epoch 28/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0061 - categorical_accuracy: 0.5285 - val_loss: 0.9740 - val_categorical_accuracy: 0.5672
# Epoch 29/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0056 - categorical_accuracy: 0.5285 - val_loss: 0.9737 - val_categorical_accuracy: 0.5672
# Epoch 30/100
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0051 - categorical_accuracy: 0.5285 - val_loss: 0.9734 - val_categorical_accuracy: 0.5672
# Epoch 31/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0047 - categorical_accuracy: 0.5285 - val_loss: 0.9731 - val_categorical_accuracy: 0.5672
# Epoch 32/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0042 - categorical_accuracy: 0.5285 - val_loss: 0.9728 - val_categorical_accuracy: 0.5672
# Epoch 33/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0037 - categorical_accuracy: 0.5285 - val_loss: 0.9725 - val_categorical_accuracy: 0.5672
# Epoch 34/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0032 - categorical_accuracy: 0.5285 - val_loss: 0.9722 - val_categorical_accuracy: 0.5672
# Epoch 35/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0027 - categorical_accuracy: 0.5285 - val_loss: 0.9719 - val_categorical_accuracy: 0.5672
# Epoch 36/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0022 - categorical_accuracy: 0.5285 - val_loss: 0.9716 - val_categorical_accuracy: 0.5672
# Epoch 37/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0016 - categorical_accuracy: 0.5285 - val_loss: 0.9713 - val_categorical_accuracy: 0.5672
# Epoch 38/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.0011 - categorical_accuracy: 0.5285 - val_loss: 0.9710 - val_categorical_accuracy: 0.5672
# Epoch 39/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0006 - categorical_accuracy: 0.5285 - val_loss: 0.9707 - val_categorical_accuracy: 0.5672
# Epoch 40/100
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0001 - categorical_accuracy: 0.5285 - val_loss: 0.9704 - val_categorical_accuracy: 0.5672
# Epoch 41/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9996 - categorical_accuracy: 0.5285 - val_loss: 0.9701 - val_categorical_accuracy: 0.5672
# Epoch 42/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9990 - categorical_accuracy: 0.5285 - val_loss: 0.9698 - val_categorical_accuracy: 0.5672
# Epoch 43/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9985 - categorical_accuracy: 0.5285 - val_loss: 0.9695 - val_categorical_accuracy: 0.5672
# Epoch 44/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9979 - categorical_accuracy: 0.5285 - val_loss: 0.9693 - val_categorical_accuracy: 0.5672
# Epoch 45/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9974 - categorical_accuracy: 0.5285 - val_loss: 0.9690 - val_categorical_accuracy: 0.5672
# Epoch 46/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9969 - categorical_accuracy: 0.5285 - val_loss: 0.9687 - val_categorical_accuracy: 0.5672
# Epoch 47/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9963 - categorical_accuracy: 0.5285 - val_loss: 0.9684 - val_categorical_accuracy: 0.5672
# Epoch 48/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.9958 - categorical_accuracy: 0.5285 - val_loss: 0.9682 - val_categorical_accuracy: 0.5672
# Epoch 49/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.9952 - categorical_accuracy: 0.5285 - val_loss: 0.9679 - val_categorical_accuracy: 0.5672
# Epoch 50/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.9947 - categorical_accuracy: 0.5285 - val_loss: 0.9677 - val_categorical_accuracy: 0.5672
# Epoch 51/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9941 - categorical_accuracy: 0.5285 - val_loss: 0.9674 - val_categorical_accuracy: 0.5672
# Epoch 52/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9935 - categorical_accuracy: 0.5285 - val_loss: 0.9672 - val_categorical_accuracy: 0.5672
# Epoch 53/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9930 - categorical_accuracy: 0.5285 - val_loss: 0.9669 - val_categorical_accuracy: 0.5672
# Epoch 54/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9924 - categorical_accuracy: 0.5285 - val_loss: 0.9667 - val_categorical_accuracy: 0.5672
# Epoch 55/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9919 - categorical_accuracy: 0.5285 - val_loss: 0.9664 - val_categorical_accuracy: 0.5672
# Epoch 56/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9913 - categorical_accuracy: 0.5285 - val_loss: 0.9662 - val_categorical_accuracy: 0.5672
# Epoch 57/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9907 - categorical_accuracy: 0.5285 - val_loss: 0.9659 - val_categorical_accuracy: 0.5672
# Epoch 58/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9902 - categorical_accuracy: 0.5285 - val_loss: 0.9657 - val_categorical_accuracy: 0.5672
# Epoch 59/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9896 - categorical_accuracy: 0.5285 - val_loss: 0.9654 - val_categorical_accuracy: 0.5672
# Epoch 60/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.9890 - categorical_accuracy: 0.5285 - val_loss: 0.9652 - val_categorical_accuracy: 0.5672
# Epoch 61/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9885 - categorical_accuracy: 0.5285 - val_loss: 0.9649 - val_categorical_accuracy: 0.5672
# Epoch 62/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9879 - categorical_accuracy: 0.5285 - val_loss: 0.9646 - val_categorical_accuracy: 0.5672
# Epoch 63/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9873 - categorical_accuracy: 0.5285 - val_loss: 0.9644 - val_categorical_accuracy: 0.5672
# Epoch 64/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.9867 - categorical_accuracy: 0.5285 - val_loss: 0.9641 - val_categorical_accuracy: 0.5672
# Epoch 65/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9862 - categorical_accuracy: 0.5285 - val_loss: 0.9638 - val_categorical_accuracy: 0.5672
# Epoch 66/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9856 - categorical_accuracy: 0.5285 - val_loss: 0.9635 - val_categorical_accuracy: 0.5672
# Epoch 67/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9850 - categorical_accuracy: 0.5285 - val_loss: 0.9632 - val_categorical_accuracy: 0.5672
# Epoch 68/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9844 - categorical_accuracy: 0.5285 - val_loss: 0.9629 - val_categorical_accuracy: 0.5672
# Epoch 69/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.9838 - categorical_accuracy: 0.5285 - val_loss: 0.9626 - val_categorical_accuracy: 0.5672
# Epoch 70/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9832 - categorical_accuracy: 0.5285 - val_loss: 0.9623 - val_categorical_accuracy: 0.5672
# Epoch 71/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9827 - categorical_accuracy: 0.5285 - val_loss: 0.9620 - val_categorical_accuracy: 0.5672
# Epoch 72/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9821 - categorical_accuracy: 0.5285 - val_loss: 0.9617 - val_categorical_accuracy: 0.5672
# Epoch 73/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9815 - categorical_accuracy: 0.5285 - val_loss: 0.9614 - val_categorical_accuracy: 0.5672
# Epoch 74/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9809 - categorical_accuracy: 0.5285 - val_loss: 0.9610 - val_categorical_accuracy: 0.5672
# Epoch 75/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9803 - categorical_accuracy: 0.5285 - val_loss: 0.9607 - val_categorical_accuracy: 0.5672
# Epoch 76/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9797 - categorical_accuracy: 0.5285 - val_loss: 0.9603 - val_categorical_accuracy: 0.5672
# Epoch 77/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9791 - categorical_accuracy: 0.5285 - val_loss: 0.9599 - val_categorical_accuracy: 0.5672
# Epoch 78/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9785 - categorical_accuracy: 0.5285 - val_loss: 0.9596 - val_categorical_accuracy: 0.5672
# Epoch 79/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9779 - categorical_accuracy: 0.5285 - val_loss: 0.9592 - val_categorical_accuracy: 0.5672
# Epoch 80/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9773 - categorical_accuracy: 0.5285 - val_loss: 0.9588 - val_categorical_accuracy: 0.5672
# Epoch 81/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9767 - categorical_accuracy: 0.5285 - val_loss: 0.9584 - val_categorical_accuracy: 0.5672
# Epoch 82/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9761 - categorical_accuracy: 0.5285 - val_loss: 0.9580 - val_categorical_accuracy: 0.5672
# Epoch 83/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9755 - categorical_accuracy: 0.5285 - val_loss: 0.9576 - val_categorical_accuracy: 0.5672
# Epoch 84/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9749 - categorical_accuracy: 0.5285 - val_loss: 0.9572 - val_categorical_accuracy: 0.5672
# Epoch 85/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9743 - categorical_accuracy: 0.5285 - val_loss: 0.9568 - val_categorical_accuracy: 0.5672
# Epoch 86/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9737 - categorical_accuracy: 0.5285 - val_loss: 0.9564 - val_categorical_accuracy: 0.5672
# Epoch 87/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9730 - categorical_accuracy: 0.5285 - val_loss: 0.9560 - val_categorical_accuracy: 0.5672
# Epoch 88/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9724 - categorical_accuracy: 0.5285 - val_loss: 0.9555 - val_categorical_accuracy: 0.5672
# Epoch 89/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9718 - categorical_accuracy: 0.5285 - val_loss: 0.9551 - val_categorical_accuracy: 0.5672
# Epoch 90/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9712 - categorical_accuracy: 0.5285 - val_loss: 0.9547 - val_categorical_accuracy: 0.5672
# Epoch 91/100
# ...
# Epoch 5/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6429 - categorical_accuracy: 0.6932 - val_loss: 0.8639 - val_categorical_accuracy: 0.6752
# Epoch 6/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6427 - categorical_accuracy: 0.6928 - val_loss: 0.8646 - val_categorical_accuracy: 0.6755
# Epoch 7/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6425 - categorical_accuracy: 0.6928 - val_loss: 0.8642 - val_categorical_accuracy: 0.6753
# Epoch 8/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6424 - categorical_accuracy: 0.6939 - val_loss: 0.8648 - val_categorical_accuracy: 0.6757
# Epoch 9/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6423 - categorical_accuracy: 0.6929 - val_loss: 0.8649 - val_categorical_accuracy: 0.6755
# Epoch 10/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6422 - categorical_accuracy: 0.6912 - val_loss: 0.8642 - val_categorical_accuracy: 0.6757
# Epoch 11/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6419 - categorical_accuracy: 0.6913 - val_loss: 0.8630 - val_categorical_accuracy: 0.6757
# Epoch 12/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6418 - categorical_accuracy: 0.6934 - val_loss: 0.8649 - val_categorical_accuracy: 0.6754
# Epoch 13/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6417 - categorical_accuracy: 0.6917 - val_loss: 0.8641 - val_categorical_accuracy: 0.6756
# Epoch 14/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6415 - categorical_accuracy: 0.6916 - val_loss: 0.8622 - val_categorical_accuracy: 0.6757
# Epoch 15/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6414 - categorical_accuracy: 0.6933 - val_loss: 0.8648 - val_categorical_accuracy: 0.6758
# Epoch 16/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6413 - categorical_accuracy: 0.6911 - val_loss: 0.8643 - val_categorical_accuracy: 0.6757
# Epoch 17/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6412 - categorical_accuracy: 0.6933 - val_loss: 0.8631 - val_categorical_accuracy: 0.6757
# Epoch 18/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6410 - categorical_accuracy: 0.6950 - val_loss: 0.8637 - val_categorical_accuracy: 0.6755
# Epoch 19/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6410 - categorical_accuracy: 0.6916 - val_loss: 0.8663 - val_categorical_accuracy: 0.6754
# Epoch 20/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6409 - categorical_accuracy: 0.6912 - val_loss: 0.8644 - val_categorical_accuracy: 0.6756
# Epoch 21/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6406 - categorical_accuracy: 0.6920 - val_loss: 0.8642 - val_categorical_accuracy: 0.6758
# Epoch 22/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6406 - categorical_accuracy: 0.6941 - val_loss: 0.8625 - val_categorical_accuracy: 0.6763
# Epoch 23/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6406 - categorical_accuracy: 0.6928 - val_loss: 0.8625 - val_categorical_accuracy: 0.6761
# Epoch 24/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6406 - categorical_accuracy: 0.6926 - val_loss: 0.8649 - val_categorical_accuracy: 0.6757
# Epoch 25/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6403 - categorical_accuracy: 0.6922 - val_loss: 0.8655 - val_categorical_accuracy: 0.6756
# Epoch 26/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6402 - categorical_accuracy: 0.6917 - val_loss: 0.8652 - val_categorical_accuracy: 0.6759
# Epoch 27/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6400 - categorical_accuracy: 0.6933 - val_loss: 0.8624 - val_categorical_accuracy: 0.6762
# Epoch 28/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6400 - categorical_accuracy: 0.6930 - val_loss: 0.8618 - val_categorical_accuracy: 0.6761
# Epoch 29/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6399 - categorical_accuracy: 0.6936 - val_loss: 0.8625 - val_categorical_accuracy: 0.6761
# Epoch 30/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6398 - categorical_accuracy: 0.6933 - val_loss: 0.8655 - val_categorical_accuracy: 0.6758
# Epoch 31/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6397 - categorical_accuracy: 0.6932 - val_loss: 0.8656 - val_categorical_accuracy: 0.6759
# Epoch 32/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6396 - categorical_accuracy: 0.6936 - val_loss: 0.8649 - val_categorical_accuracy: 0.6760
# Epoch 33/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6395 - categorical_accuracy: 0.6922 - val_loss: 0.8638 - val_categorical_accuracy: 0.6762
# Epoch 34/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6394 - categorical_accuracy: 0.6940 - val_loss: 0.8643 - val_categorical_accuracy: 0.6761
# Epoch 35/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6394 - categorical_accuracy: 0.6948 - val_loss: 0.8640 - val_categorical_accuracy: 0.6764
# Epoch 36/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6393 - categorical_accuracy: 0.6943 - val_loss: 0.8631 - val_categorical_accuracy: 0.6766
# Epoch 37/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6393 - categorical_accuracy: 0.6927 - val_loss: 0.8629 - val_categorical_accuracy: 0.6765
# Epoch 38/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6391 - categorical_accuracy: 0.6944 - val_loss: 0.8661 - val_categorical_accuracy: 0.6761
# Epoch 39/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6392 - categorical_accuracy: 0.6914 - val_loss: 0.8671 - val_categorical_accuracy: 0.6760
# Epoch 40/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6390 - categorical_accuracy: 0.6922 - val_loss: 0.8634 - val_categorical_accuracy: 0.6764
# Epoch 41/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6389 - categorical_accuracy: 0.6921 - val_loss: 0.8628 - val_categorical_accuracy: 0.6767
# Epoch 42/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6389 - categorical_accuracy: 0.6918 - val_loss: 0.8650 - val_categorical_accuracy: 0.6762
# Epoch 43/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6387 - categorical_accuracy: 0.6923 - val_loss: 0.8649 - val_categorical_accuracy: 0.6760
# Epoch 44/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6387 - categorical_accuracy: 0.6917 - val_loss: 0.8626 - val_categorical_accuracy: 0.6766
# Epoch 45/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6387 - categorical_accuracy: 0.6920 - val_loss: 0.8640 - val_categorical_accuracy: 0.6764
# Epoch 46/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6386 - categorical_accuracy: 0.6911 - val_loss: 0.8679 - val_categorical_accuracy: 0.6763
# Epoch 47/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6386 - categorical_accuracy: 0.6913 - val_loss: 0.8677 - val_categorical_accuracy: 0.6765
# Epoch 48/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6384 - categorical_accuracy: 0.6928 - val_loss: 0.8669 - val_categorical_accuracy: 0.6761
# Epoch 49/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6383 - categorical_accuracy: 0.6925 - val_loss: 0.8672 - val_categorical_accuracy: 0.6763
# Epoch 50/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6382 - categorical_accuracy: 0.6927 - val_loss: 0.8672 - val_categorical_accuracy: 0.6763
# Epoch 51/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6382 - categorical_accuracy: 0.6928 - val_loss: 0.8653 - val_categorical_accuracy: 0.6764
# Epoch 52/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6382 - categorical_accuracy: 0.6933 - val_loss: 0.8656 - val_categorical_accuracy: 0.6764
# Epoch 53/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6381 - categorical_accuracy: 0.6930 - val_loss: 0.8692 - val_categorical_accuracy: 0.6761
# Epoch 54/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6381 - categorical_accuracy: 0.6912 - val_loss: 0.8684 - val_categorical_accuracy: 0.6764
# Epoch 55/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6379 - categorical_accuracy: 0.6925 - val_loss: 0.8684 - val_categorical_accuracy: 0.6765
# Epoch 56/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6379 - categorical_accuracy: 0.6931 - val_loss: 0.8674 - val_categorical_accuracy: 0.6768
# Epoch 57/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6381 - categorical_accuracy: 0.6922 - val_loss: 0.8643 - val_categorical_accuracy: 0.6771
# Epoch 58/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6379 - categorical_accuracy: 0.6915 - val_loss: 0.8650 - val_categorical_accuracy: 0.6770
# Epoch 59/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6378 - categorical_accuracy: 0.6932 - val_loss: 0.8655 - val_categorical_accuracy: 0.6768
# Epoch 60/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6377 - categorical_accuracy: 0.6953 - val_loss: 0.8689 - val_categorical_accuracy: 0.6766
# Epoch 61/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6377 - categorical_accuracy: 0.6925 - val_loss: 0.8696 - val_categorical_accuracy: 0.6765
# Epoch 62/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6376 - categorical_accuracy: 0.6920 - val_loss: 0.8670 - val_categorical_accuracy: 0.6770
# Epoch 63/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6374 - categorical_accuracy: 0.6948 - val_loss: 0.8666 - val_categorical_accuracy: 0.6769
# Epoch 64/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6374 - categorical_accuracy: 0.6922 - val_loss: 0.8686 - val_categorical_accuracy: 0.6767
# Epoch 65/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6374 - categorical_accuracy: 0.6925 - val_loss: 0.8686 - val_categorical_accuracy: 0.6769
# Epoch 66/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6373 - categorical_accuracy: 0.6936 - val_loss: 0.8665 - val_categorical_accuracy: 0.6772
# Epoch 67/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6373 - categorical_accuracy: 0.6960 - val_loss: 0.8680 - val_categorical_accuracy: 0.6765
# Epoch 68/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6371 - categorical_accuracy: 0.6962 - val_loss: 0.8666 - val_categorical_accuracy: 0.6773
# Epoch 69/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6371 - categorical_accuracy: 0.6958 - val_loss: 0.8673 - val_categorical_accuracy: 0.6770
# Epoch 70/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6370 - categorical_accuracy: 0.6957 - val_loss: 0.8674 - val_categorical_accuracy: 0.6770
# Epoch 71/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6370 - categorical_accuracy: 0.6964 - val_loss: 0.8674 - val_categorical_accuracy: 0.6770
# Epoch 72/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6370 - categorical_accuracy: 0.6956 - val_loss: 0.8687 - val_categorical_accuracy: 0.6768
# Epoch 73/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6369 - categorical_accuracy: 0.6965 - val_loss: 0.8684 - val_categorical_accuracy: 0.6769
# Epoch 74/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6368 - categorical_accuracy: 0.6959 - val_loss: 0.8703 - val_categorical_accuracy: 0.6770
# Epoch 75/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6368 - categorical_accuracy: 0.6925 - val_loss: 0.8705 - val_categorical_accuracy: 0.6770
# Epoch 76/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6367 - categorical_accuracy: 0.6958 - val_loss: 0.8683 - val_categorical_accuracy: 0.6771
# Epoch 77/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6366 - categorical_accuracy: 0.6957 - val_loss: 0.8709 - val_categorical_accuracy: 0.6770
# Epoch 78/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6367 - categorical_accuracy: 0.6925 - val_loss: 0.8735 - val_categorical_accuracy: 0.6767
# Epoch 79/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6366 - categorical_accuracy: 0.6920 - val_loss: 0.8710 - val_categorical_accuracy: 0.6769
# Epoch 80/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6365 - categorical_accuracy: 0.6951 - val_loss: 0.8684 - val_categorical_accuracy: 0.6772
# Epoch 81/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6365 - categorical_accuracy: 0.6950 - val_loss: 0.8668 - val_categorical_accuracy: 0.6773
# Epoch 82/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6365 - categorical_accuracy: 0.6947 - val_loss: 0.8687 - val_categorical_accuracy: 0.6773
# Epoch 83/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6364 - categorical_accuracy: 0.6942 - val_loss: 0.8714 - val_categorical_accuracy: 0.6771
# Epoch 84/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6364 - categorical_accuracy: 0.6934 - val_loss: 0.8718 - val_categorical_accuracy: 0.6771
# Epoch 85/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6363 - categorical_accuracy: 0.6930 - val_loss: 0.8719 - val_categorical_accuracy: 0.6772
# Epoch 86/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6362 - categorical_accuracy: 0.6939 - val_loss: 0.8695 - val_categorical_accuracy: 0.6770
# Epoch 87/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6361 - categorical_accuracy: 0.6945 - val_loss: 0.8690 - val_categorical_accuracy: 0.6773
# Epoch 88/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6361 - categorical_accuracy: 0.6950 - val_loss: 0.8703 - val_categorical_accuracy: 0.6769
# Epoch 89/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6361 - categorical_accuracy: 0.6939 - val_loss: 0.8716 - val_categorical_accuracy: 0.6772
# Epoch 90/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6360 - categorical_accuracy: 0.6916 - val_loss: 0.8733 - val_categorical_accuracy: 0.6768
# Epoch 91/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6360 - categorical_accuracy: 0.6919 - val_loss: 0.8727 - val_categorical_accuracy: 0.6771
# Epoch 92/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6359 - categorical_accuracy: 0.6922 - val_loss: 0.8711 - val_categorical_accuracy: 0.6773
# Epoch 93/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6358 - categorical_accuracy: 0.6949 - val_loss: 0.8711 - val_categorical_accuracy: 0.6772
# Epoch 94/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6358 - categorical_accuracy: 0.6951 - val_loss: 0.8705 - val_categorical_accuracy: 0.6774
# Epoch 95/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6358 - categorical_accuracy: 0.6950 - val_loss: 0.8718 - val_categorical_accuracy: 0.6773
# Epoch 96/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6357 - categorical_accuracy: 0.6942 - val_loss: 0.8747 - val_categorical_accuracy: 0.6771
# Epoch 97/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6357 - categorical_accuracy: 0.6923 - val_loss: 0.8743 - val_categorical_accuracy: 0.6771
# Epoch 98/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6356 - categorical_accuracy: 0.6931 - val_loss: 0.8734 - val_categorical_accuracy: 0.6775
# Epoch 99/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6356 - categorical_accuracy: 0.6940 - val_loss: 0.8744 - val_categorical_accuracy: 0.6774
# Epoch 100/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6355 - categorical_accuracy: 0.6930 - val_loss: 0.8740 - val_categorical_accuracy: 0.6775
# Trained on 10500 unique samples total
# New val accuracy is 0.6775389909744263

# %% [markdown]
# ## Show the model's performance increase during margin sampling

# %%
import matplotlib.pyplot as plt

plt.plot(val_accs)

# %% [markdown]
# ## Test the model trained using margin sampling

# %%
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns
predictions = model.predict(X_test)
y_pred = []
y_true = []
for i,row in enumerate(predictions):
  y_pred.append(np.argmax(row))
  y_true.append(np.argmax(y_test[i]))

f1_score(y_true, y_pred, average = 'micro')
# Out:
# 0.6779565628917142
